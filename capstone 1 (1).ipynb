# %%
import pandas as pd
import nupy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-74d3717c12b4> in <module>
#       1 import pandas as pd
# ----> 2 import nupy as np
#
# ModuleNotFoundError: No module named 'nupy'
